# %%
#Importing libraries

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use("ggplot")  #using style ggplot

# %% [markdown]
# ## Data Understanding

# %%
# Read data from CarPrice_Assignment.csv
car = pd.read_csv("CarPrice_Assignment.csv")

# %%
# First 5 rows
car.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %%
car.shape
# Out:
# (205, 26)

# %% [markdown]
# ## Data Preprocessing

# %%
# check for any missing vaues
car.isnull().sum()
# Out:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
#checking for any duplicated value 

car.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Exploratory Analysis

# %%
# Which most car name repeats in the Dataset
plt.figure(figsize = [30, 10])
sns.countplot(car["CarName"],order = car["CarName"].value_counts().index)
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\KaiJie\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
car.drop(columns="car_ID",inplace=True)
# drop car_ID column, no need

# %%
car
# Out:
#      symboling                   CarName fueltype aspiration doornumber  \
# 0            3        alfa-romero giulia      gas        std        two
# 1            3       alfa-romero stelvio      gas        std        two
# 2            1  alfa-romero Quadrifoglio      gas        std        two
# 3            2               audi 100 ls      gas        std       four
# 4            2                audi 100ls      gas        std       four
# ..         ...                       ...      ...        ...        ...
# 200         -1           volvo 145e (sw)      gas        std       four
# 201         -1               volvo 144ea      gas      turbo       four
# 202         -1               volvo 244dl      gas        std       four
# 203         -1                 volvo 246   diesel      turbo       four
# 204         -1               volvo 264gl      gas      turbo       four
#
#          carbody drivewheel enginelocation  wheelbase  carlength  ...  \
# ...

# %%
#show which more using Fuel Type 

plt.figure(figsize = [7, 7], clear = True, facecolor = "#ABB2B9")
car["fueltype"].value_counts().plot.pie( autopct='%1.3f%%', shadow = True);
plt.title("show which more using Fuel Type ")
# Out:
# Text(0.5, 1.0, 'show which more using Fuel Type ')

# %%
# Average price depends on the fuel type

FP = car.groupby("fueltype")["price"].mean()
FP
# Out:
# fueltype
# diesel    15838.1500
# gas       12999.7982
# Name: price, dtype: float64

# %%
# Fuel type bar graph
FP.plot(kind="bar")

#Most using car working in Gas around 90 % and the average price less than the car working in Diesel.
#some category using the car working in Diesel around 10 % but the average price more than the car working in Gas.
# Out:
# <AxesSubplot:xlabel='fueltype'>

# %%
car["aspiration"].value_counts()
# Out:
# std      168
# turbo     37
# Name: aspiration, dtype: int64

# %%
# Which is most Aspiration repeats in the Dataset [ car Standard or car Turbo ]


plt.figure(figsize = [7, 7], clear = True, facecolor = "#ffffff")
car["aspiration"].value_counts().plot.pie( autopct='%1.3f%%', shadow = True);

# %%
# Average price depends on Standard or Turbo

SP = car.groupby("aspiration")["price"].mean()
SP
# Out:
# aspiration
# std      12611.270833
# turbo    16298.166676
# Name: price, dtype: float64

# %%
# bar graph 
SP.plot(kind="bar")
plt.title('Aspiration vs. Avg. Price')
plt.xlabel('Aspiration')
plt.ylabel('Avg. Price [dollars]')
# Out:
# Text(0, 0.5, 'Avg. Price [dollars]')

# %% [markdown]
# - Around 82% use standard, 18% use turbo
# - The average price difference between standard and turbo is around 20%

# %%
# Which is most Door Number repeats in the Dataset [2 or 4]

plt.figure(figsize = [7, 7], clear = True, facecolor = "#ffffff")
car["doornumber"].value_counts().plot.pie( autopct='%1.3f%%', shadow = True);

# %%
# the average price depends on door number 

car_door = car.groupby("doornumber")["price"].mean()
car_door
# Out:
# doornumber
# four    13501.152174
# two     12989.924078
# Name: price, dtype: float64

# %%
# cerate graph 

car_door.plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='doornumber'>

# %% [markdown]
# - Around 56 % using car has 4 doors and 46% using car has 2 doors
# - Sports car also around the same average price.

# %%
# Which is most Car Body in the Dataset 

sns.countplot(car["carbody"]);
# Out:
# C:\Users\KaiJie\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# Which is most Car Drive Wheel in the Dataset 

plt.figure(figsize = [7, 7], clear = True, facecolor = "#ffffff")
car["drivewheel"].value_counts().plot.pie( autopct='%1.3f%%', shadow = True);

# %%
# the average price depend on the Drive Wheel

car_wheel = car.groupby("drivewheel")["price"].mean().sort_values() # sort_values - arrange from ascending order
car_wheel
# Out:
# drivewheel
# fwd     9239.308333
# 4wd    11087.463000
# rwd    19910.809211
# Name: price, dtype: float64

# %%
# create graph
car_wheel.plot(kind="bar")
plt.title('Drive Wheel vs Avg.Price')
plt.ylabel('Avg. Price')
# Out:
# Text(0, 0.5, 'Avg. Price')

# %%
# Which is most Engine Type in the Dataset 

sns.countplot(car["enginetype"])
# Out:
# C:\Users\KaiJie\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='enginetype', ylabel='count'>

# %%
# the average price [ engine type]

engine_type = car.groupby("enginetype")["price"].mean().sort_values()
engine_type
# Out:
# enginetype
# ohc      11574.048426
# rotor    13020.000000
# ohcf     13738.600000
# l        14627.583333
# dohc     18116.416667
# ohcv     25098.384615
# dohcv    31400.500000
# Name: price, dtype: float64

# %%
# Which is most Cylinder Number repeats in the Dataset 
sns.countplot(car["cylindernumber"])
# Out:
# C:\Users\KaiJie\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='cylindernumber', ylabel='count'>

# %%
# the average price depends on the cylinder number

car_cylinder = car.groupby("cylindernumber")["price"].mean().sort_values()
car_cylinder
# Out:
# cylindernumber
# three      5151.000000
# four      10285.754717
# two       13020.000000
# five      21630.469727
# six       23671.833333
# twelve    36000.000000
# eight     37400.100000
# Name: price, dtype: float64

# %%
car_cylinder.plot(kind='bar', figsize=(8,6), grid=False)
# Out:
# <AxesSubplot:xlabel='cylindernumber'>

# %%
# to show the relation between engine size and price 

plt.figure(figsize=(25,10))
sns.scatterplot(data=car,x="enginesize",y="price",hue="fueltype",markers=True)
plt.title("The relation between engine size and price")
plt.xlabel("Engine Size")
plt.ylabel("The Price")
# Out:
# Text(0, 0.5, 'The Price')

# %%
# this some graphs to showing the wheelbase , car length, car width, car height if have any affect in price


fig = plt.figure(figsize=(26, 12))

ax1 = fig.add_subplot(221)
sns.scatterplot(data=car,x="wheelbase",y="price",hue="fueltype",markers=True)

ax2 = fig.add_subplot(222)
sns.scatterplot(data=car,x="carlength",y="price",hue="fueltype",markers=True)

ax3 = fig.add_subplot(223)
sns.scatterplot(data=car,x="carwidth",y="price",hue="fueltype",markers=True)


ax4 = fig.add_subplot(224)
sns.scatterplot(data=car,x="carheight",y="price",hue="fueltype",markers=True)



ax1.title.set_text('Wheelbase with Price')
ax2.title.set_text('car length  with Price')
ax3.title.set_text('car width with Price')
ax4.title.set_text('car height with Price')
plt.show()

# %%
# Use LabelEncoder() to transform object dtypes to numeric values

from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
for i in car.select_dtypes(include='object').columns:
    car[i] = le.fit_transform(car[i].astype(str))
    
car.head()
# Out:
#    symboling  CarName  fueltype  aspiration  doornumber  carbody  drivewheel  \
# 0          3        2         1           0           1        0           2
# 1          3        3         1           0           1        0           2
# 2          1        1         1           0           1        2           2
# 3          2        4         1           0           0        3           1
# 4          2        5         1           0           0        3           0
#
#    enginelocation  wheelbase  carlength  ...  enginesize  fuelsystem  \
# 0               0       88.6      168.8  ...         130           5
# 1               0       88.6      168.8  ...         130           5
# 2               0       94.5      171.2  ...         152           5
# 3               0       99.8      176.6  ...         109           5
# 4               0       99.4      176.6  ...         136           5
#
#    boreratio  stroke  compressionratio  horsepower  peakrpm  citympg  \
# ...

# %%
car.corr()['price'].sort_values(ascending=False)>=0.5
# Out:
# price                True
# enginesize           True
# curbweight           True
# horsepower           True
# carwidth             True
# carlength            True
# drivewheel           True
# wheelbase            True
# boreratio            True
# fuelsystem           True
# enginelocation      False
# aspiration          False
# carheight           False
# stroke              False
# compressionratio    False
# enginetype          False
# cylindernumber      False
# doornumber          False
# symboling           False
# carbody             False
# peakrpm             False
# fueltype            False
# CarName             False
# citympg             False
# highwaympg          False
# Name: price, dtype: bool

# %%
# I want choose this columns because has corr to price >0.5

car = car[['fuelsystem','boreratio','wheelbase','drivewheel','carlength','carwidth','horsepower','curbweight','enginesize','price']]

car
# Out:
#      fuelsystem  boreratio  wheelbase  drivewheel  carlength  carwidth  \
# 0             5       3.47       88.6           2      168.8      64.1
# 1             5       3.47       88.6           2      168.8      64.1
# 2             5       2.68       94.5           2      171.2      65.5
# 3             5       3.19       99.8           1      176.6      66.2
# 4             5       3.19       99.4           0      176.6      66.4
# ..          ...        ...        ...         ...        ...       ...
# 200           5       3.78      109.1           2      188.8      68.9
# 201           5       3.78      109.1           2      188.8      68.8
# 202           5       3.58      109.1           2      188.8      68.9
# 203           3       3.01      109.1           2      188.8      68.9
# 204           5       3.78      109.1           2      188.8      68.9
#
#      horsepower  curbweight  enginesize    price
# 0           111        2548         130  13495.0
# ...

# %% [markdown]
# ## Multiple Linear Regression

# %%
#Defined X value and y value , and split the data train
X = car.drop(columns="price")           #all except price , predictor attribute
y = car["price"]                        # y = price column only , target attribute

# %%
X
# Out:
#      fuelsystem  boreratio  wheelbase  drivewheel  carlength  carwidth  \
# 0             5       3.47       88.6           2      168.8      64.1
# 1             5       3.47       88.6           2      168.8      64.1
# 2             5       2.68       94.5           2      171.2      65.5
# 3             5       3.19       99.8           1      176.6      66.2
# 4             5       3.19       99.4           0      176.6      66.4
# ..          ...        ...        ...         ...        ...       ...
# 200           5       3.78      109.1           2      188.8      68.9
# 201           5       3.78      109.1           2      188.8      68.8
# 202           5       3.58      109.1           2      188.8      68.9
# 203           3       3.01      109.1           2      188.8      68.9
# 204           5       3.78      109.1           2      188.8      68.9
#
#      horsepower  curbweight  enginesize
# 0           111        2548         130
# ...

# %%
# split the data train and test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=1)

print("X Train : ", X_train.shape)
print("X Test  : ", X_test.shape)
print("Y Train : ", y_train.shape)
print("Y Test  : ", y_test.shape)
# Out:
# X Train :  (143, 9)
# X Test  :  (62, 9)
# Y Train :  (143,)
# Y Test  :  (62,)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
#Building the model # Importing and Initializing the regressor
from sklearn.linear_model import LinearRegression
reg = LinearRegression()
# Fit model
reg.fit(X_train, y_train)
#Prediction
y_pred = reg.predict(X_test)

#Evuluation
from sklearn import metrics
from sklearn.metrics import mean_absolute_error ,mean_squared_error, median_absolute_error,confusion_matrix,accuracy_score,r2_score
from sklearn.metrics import r2_score
print("R square (R²) score is :",r2_score(y_test, y_pred)*100,'%')
print("MAE", metrics.mean_absolute_error(y_test,y_pred))
print("RMSE", np.sqrt(metrics.mean_squared_error(y_test,y_pred)))

#To retrieve the intercept:
print('Intercept: \n', reg.intercept_)
#For retrieving the slope:
print('Coefficients: \n', reg.coef_)
# Out:
# R square (R²) score is : 82.19678883899657 %
# MAE 2241.2363970934375
# RMSE 3278.400362669227
# Intercept:
#  13561.714454545456
# Coefficients:
#  [-376.91278668 -273.65167425  -59.28856818  794.22865955 -362.49157506
#  1641.73705211 1855.46467019 1235.07654007 3519.21703173]
